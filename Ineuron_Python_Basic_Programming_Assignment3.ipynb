# %% [markdown]
# **Ineuron Python Basic Programming Assignment 3**

# %% [markdown]
# 1. Write a Python Program to Check if a Number is Positive, Negative or Zero?

# %%
number = int(input("Enter value for number: "))
if number > 0:
  print("Number is positive")
elif number < 0: 
  print("Number is negative")
else:
  print("Number is zero")
# Out:
# Enter value for number: 0
# Number is zero

# %% [markdown]
# 2. Write a Python Program to Check if a Number is Odd or Even?

# %%
number = int(input("Enter value for number: "))
if number % 2 == 0:
  print("EVEN NUMBER")
else: 
  print("ODD NUMBER")
# Out:
# Enter value for number: 44
# EVEN NUMBER

# %% [markdown]
# 3. Write a Python Program to Check Leap Year?

# %%
year = int(input("Enter value for number: "))
if year % 4 == 0:
  print("LEAP YEAR")
else: 
  print("ITS NOT A LEAP YEAR")
# Out:
# Enter value for number: 2020
# LEAP YEAR

# %% [markdown]
# 4. Write a Python Program to Check Prime Number?

# %%
number = int(input("Enter a no."))
for i in range(2,number):
    if number % i == 0:
        print("{} is not a prime no.".format(number))
        break
    else:
        print("{} is  a prime no.".format(number))
        break
# Out:
# Enter a no.8
# 8 is not a prime no.

# %% [markdown]
# 5. Write a Python Program to Print all Prime Numbers in an Interval of 1-10000?

# %%
a = int(input("Enter a number1: ")) 
b = int(input("Enter a number2: ")) 
for num in range(a,b):  
    if num > 1:
        for i in range(2,num):
            if (num%i) == 0:
                print([num],'is not a prime')                
                break
        else:
            print([num],'is a prime number')
# Out:
# Streaming output truncated to the last 5000 lines.
# [5000] is not a prime
# [5001] is not a prime
# [5002] is not a prime
# [5003] is a prime number
# [5004] is not a prime
# [5005] is not a prime
# [5006] is not a prime
# [5007] is not a prime
# [5008] is not a prime
# [5009] is a prime number
# [5010] is not a prime
# [5011] is a prime number
# [5012] is not a prime
# [5013] is not a prime
# [5014] is not a prime
# [5015] is not a prime
# [5016] is not a prime
# [5017] is not a prime
# [5018] is not a prime
# [5019] is not a prime
# [5020] is not a prime
# [5021] is a prime number
# [5022] is not a prime
# [5023] is a prime number
# [5024] is not a prime
# [5025] is not a prime
# [5026] is not a prime
# [5027] is not a prime
# [5028] is not a prime
# [5029] is not a prime
# [5030] is not a prime
# [5031] is not a prime
# [5032] is not a prime
# [5033] is not a prime
# [5034] is not a prime
# [5035] is not a prime
# [5036] is not a prime
# [5037] is not a prime
# ...
